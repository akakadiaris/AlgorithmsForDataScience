# %% [markdown]
# # Max Flow Applications
#
# The purpose of this assignment is to investigate applications of finding a Max Flow. The problem asks you to design and implement an algorithm for shipping a material between nodes with different supply and demand requirements.
#
# * Please write code *only* in the bodies of the two functions, that is, following the TODO comments.
# * Be careful not to use variables defined outside of the functions.
# * Breaking the two above rules may lead to 0 grades.

# %%
# I ADDED
with open('contiguous-usa.dat', 'r') as usa_file:
    for line in usa_file:
        print(line.strip())
# Out:
# AL FL
# AL GA
# AL MS
# AL TN
# AR LA
# AR MO
# AR MS
# AR OK
# AR TN
# AR TX
# AZ CA
# AZ NM
# AZ NV
# AZ UT
# CA NV
# CA OR
# CO KS
# CO NE
# CO NM
# CO OK
# CO UT
# CO WY
# CT MA
# CT NY
# CT RI
# DC MD
# DC VA
# DE MD
# DE NJ
# DE PA
# FL GA
# GA NC
# GA SC
# GA TN
# IA IL
# IA MN
# IA MO
# IA NE
# IA SD
# IA WI
# ID MT
# ID NV
# ID OR
# ID UT
# ID WA
# ID WY
# IL IN
# IL KY
# IL MO
# IL WI
# IN KY
# IN MI
# IN OH
# KS MO
# KS NE
# KS OK
# KY MO
# KY OH
# KY TN
# KY VA
# KY WV
# LA MS
# LA TX
# MA NH
# MA NY
# MA RI
# MA VT
# MD PA
# MD VA
# MD WV
# ME NH
# MI OH
# MI WI
# MN ND
# MN SD
# MN WI
# MO NE
# MO OK
# MO TN
# MS TN
# MT ND
# MT SD
# MT WY
# NC SC
# NC TN
# NC VA
# ND SD
# NE SD
# NE WY
# NH VT
# NJ NY
# NJ PA
# NM OK
# NM TX
# NV OR
# NV UT
# NY PA
# NY VT
# OH PA
# OH WV
# OK TX
# OR WA
# PA WV
# SD WY
# TN VA
# UT WY
# VA WV

# %% [markdown]
# ## Movie distribution
#
# First solve Problem 2 from HW4 (theory part).
#
# Now suppose a movie distributor would like to ship a copy of a film from CA to every other state. There are therefore 48 units to ship out of CA, and each other state receives 1 unit.
#
# The dataset contiguous-usa.dat lists the adjacent states in the US. Each line lists two adjacent states; thus AK and HI are omitted, but DC is included in the data. The following code reads in the graph of US states.

# %%
import networkx as nx
G = nx.Graph()

usa = open('contiguous-usa.dat')
for line in usa:
    s1, s2 = line.strip().split()
    G.add_edge(s1, s2)

# %% [markdown]
# We now encode the demands into the graph.

# %%
for state in G.nodes():
    if state != 'CA':
        G.nodes[state]['demand'] = 1
G.nodes['CA']['demand'] = -48

# %% [markdown]
# We will assign a uniform capacity of 16 to each edge. Since CA has only three adjacent states, this is the smallest possible uniform capacity that allows one to ship all 48 units out of CA. As we have created an undirected graph, and flows have directions, we first convert the graph to a directed graph.

# %%
G = nx.DiGraph(G)
uniform_capacity = 16
for (s1, s2) in G.edges():
    G.edges[s1, s2]['capacity'] = uniform_capacity

# %% [markdown]
# Complete the following function to implement your algorithm to find a flow with demands. Your function should work correctly for any input, not just the movie instance considered here. As always, you are encouraged to define auxiliary functions as needed for clarity.

# %%
def flow_with_demands(graph):
    """Computes a flow with demands over the given graph.
    
    Args:
        graph: A directed graph with nodes annotated with 'demand' properties and edges annotated with 'capacity' 
            properties.
        
    Returns:
        A dict of dicts containing the flow on each edge. For instance, flow[s1][s2] should provide the flow along
        edge (s1, s2).
        
    Raises:
        NetworkXUnfeasible: An error is thrown if there is no flow satisfying the demands.
    """
    # Convert the graph to a residual graph
    residual_graph = graph.copy()
    for (s1, s2) in graph.edges():
        # Initialize flow to 0 on each edge
        graph.edges[s1, s2]['flow'] = 0
        # Add reverse edge with capacity 0
        residual_graph.add_edge(s2, s1, capacity=0, flow=0)

    # Augment the flow until the demands are satisfied
    while True:
        try:
            path = nx.shortest_path(residual_graph, source='CA', target=None, weight='weight')
        except nx.NetworkXNoPath:
            break

        # Find the minimum capacity along the augmenting path
        min_capacity = min(residual_graph.get_edge_data(u, v)['capacity'] for u, v in zip(path[:-1], path[1:]))

        # Update the flow along the augmenting path
        for u, v in zip(path, path[1:]):
            residual_graph.edges[u, v]['flow'] += min_capacity
            residual_graph.edges[v, u]['flow'] -= min_capacity

        # Update the capacities on the residual graph
        for u, v in zip(path, path[1:]):
            residual_graph.edges[u, v]['capacity'] -= min_capacity
            residual_graph.edges[v, u]['capacity'] += min_capacity

    # Check if the demands are satisfied
    for state in graph.nodes():
        if state != 'CA':
            total_flow = sum(residual_graph.edges[state, v]['flow'] for v in residual_graph.successors(state))
            if total_flow != graph.nodes[state]['demand']:
                raise NetworkXUnfeasible("Demands cannot be satisfied.")

    # Return the flow dictionary
    flow = {u: {v: residual_graph.edges[u, v]['flow'] for v in residual_graph.successors(u)} for u in graph.nodes()}
    return flow

# %% [markdown]
# To verify that your solution is correct, implement a function that computes the total flow into each node (which will be negative for supply nodes).

# %%
def divergence(flow):
    """Computes the total flow into each node according to the given flow dict.
    
    Args:
        flow: the flow dict recording flow between nodes.
        
    Returns:
        A dict of the net flow into each node.
    """
    net_flow = {node: sum(flow[other_node][node] for other_node in flow if node in flow[other_node]) -
                        sum(flow[node][other_node] for other_node in flow[node]) for node in flow}
    return net_flow

# %% [markdown]
# The following code performs a sanity check on your function (but does not completely confirm correctness).

# %%
flow = flow_with_demands(G)
div = divergence(flow)
print ("Flow satisfies all demands:", all(div[n] == G.nodes[n]['demand'] for n in G.nodes()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 flow = flow_with_demands(G)
#       2 div = divergence(flow)
#       3 print ("Flow satisfies all demands:", all(div[n] == G.nodes[n]['demand'] for n in G.nodes()))
#
# Cell In[13], line 31, in flow_with_demands(graph)
#      28     break
#      30 # Find the minimum capacity along the augmenting path
# ---> 31 min_capacity = min(residual_graph.get_edge_data(u, v)['capacity'] for u, v in zip(path[:-1], path[1:]))
#      33 # Update the flow along the augmenting path
#      34 for u, v in zip(path, path[1:]):
#
# TypeError: unhashable type: 'slice'

# %%
flow = flow_with_demands(G)
div = divergence(flow)

print("Node demands:", {n: G.nodes[n]['demand'] for n in G.nodes()})
print("Divergence:", div)
print("Flow satisfies all demands:", all(div[n] == G.nodes[n]['demand'] for n in G.nodes()))
# Out:
# Flow at AL: {'FL': 0, 'GA': 0, 'MS': 0, 'TN': 0}, Original Demand: 1
# Flow at FL: {'AL': 0, 'GA': 0}, Original Demand: 1
# Flow at GA: {'AL': 0, 'FL': 0, 'NC': 0, 'SC': 0, 'TN': 0}, Original Demand: 1
# Flow at MS: {'AL': 0, 'AR': 0, 'LA': 0, 'TN': 0}, Original Demand: 1
# Flow at TN: {'AL': 0, 'AR': 0, 'GA': 0, 'KY': 0, 'MO': 0, 'MS': 0, 'NC': 0, 'VA': 0}, Original Demand: 1
# Flow at AR: {'LA': 0, 'MO': 0, 'MS': 0, 'OK': 0, 'TN': 0, 'TX': 0}, Original Demand: 1
# Flow at LA: {'AR': 0, 'MS': 0, 'TX': 0}, Original Demand: 1
# Flow at MO: {'AR': 0, 'IA': 0, 'IL': 0, 'KS': 0, 'KY': 0, 'NE': 0, 'OK': 0, 'TN': 0}, Original Demand: 1
# Flow at OK: {'AR': 0, 'CO': 0, 'KS': 0, 'MO': 0, 'NM': 0, 'TX': 0}, Original Demand: 1
# Flow at TX: {'AR': 0, 'LA': 0, 'NM': 0, 'OK': 0}, Original Demand: 1
# Flow at AZ: {'CA': 0, 'NM': 0, 'NV': 0, 'UT': 0}, Original Demand: 1
# Flow at CA: {'AZ': 0, 'NV': 0, 'OR': 0, 'sink_connector': 0}, Original Demand: -48
# Flow at NM: {'AZ': 0, 'CO': 0, 'OK': 0, 'TX': 0}, Original Demand: 1
# Flow at NV: {'AZ': 0, 'CA': 0, 'ID': 0, 'OR': 0, 'UT': 0}, Original Demand: 1
# Flow at UT: {'AZ': 0, 'CO': 0, 'ID': 0, 'NV': 0, 'WY': 0}, Original Demand: 1
# Flow at OR: {'CA': 0, 'ID': 0, 'NV': 0, 'WA': 0}, Original Demand: 1
# Flow at CO: {'KS': 0, 'NE': 0, 'NM': 0, 'OK': 0, 'UT': 0, 'WY': 0}, Original Demand: 1
# Flow at KS: {'CO': 0, 'MO': 0, 'NE': 0, 'OK': 0}, Original Demand: 1
# Flow at NE: {'CO': 0, 'IA': 0, 'KS': 0, 'MO': 0, 'SD': 0, 'WY': 0}, Original Demand: 1
# Flow at WY: {'CO': 0, 'ID': 0, 'MT': 0, 'NE': 0, 'SD': 0, 'UT': 0}, Original Demand: 1
# Flow at CT: {'MA': 0, 'NY': 0, 'RI': 0}, Original Demand: 1
# Flow at MA: {'CT': 0, 'NH': 0, 'NY': 0, 'RI': 0, 'VT': 0}, Original Demand: 1
# Flow at NY: {'CT': 0, 'MA': 0, 'NJ': 0, 'PA': 0, 'VT': 0}, Original Demand: 1
# Flow at RI: {'CT': 0, 'MA': 0}, Original Demand: 1
# Flow at DC: {'MD': 0, 'VA': 0}, Original Demand: 1
# Flow at MD: {'DC': 0, 'DE': 0, 'PA': 0, 'VA': 0, 'WV': 0}, Original Demand: 1
# Flow at VA: {'DC': 0, 'KY': 0, 'MD': 0, 'NC': 0, 'TN': 0, 'WV': 0}, Original Demand: 1
# Flow at DE: {'MD': 0, 'NJ': 0, 'PA': 0}, Original Demand: 1
# Flow at NJ: {'DE': 0, 'NY': 0, 'PA': 0}, Original Demand: 1
# Flow at PA: {'DE': 0, 'MD': 0, 'NJ': 0, 'NY': 0, 'OH': 0, 'WV': 0}, Original Demand: 1
# Flow at NC: {'GA': 0, 'SC': 0, 'TN': 0, 'VA': 0}, Original Demand: 1
# Flow at SC: {'GA': 0, 'NC': 0}, Original Demand: 1
# Flow at IA: {'IL': 0, 'MN': 0, 'MO': 0, 'NE': 0, 'SD': 0, 'WI': 0}, Original Demand: 1
# Flow at IL: {'IA': 0, 'IN': 0, 'KY': 0, 'MO': 0, 'WI': 0}, Original Demand: 1
# Flow at MN: {'IA': 0, 'ND': 0, 'SD': 0, 'WI': 0}, Original Demand: 1
# Flow at SD: {'IA': 0, 'MN': 0, 'MT': 0, 'ND': 0, 'NE': 0, 'WY': 0}, Original Demand: 1
# Flow at WI: {'IA': 0, 'IL': 0, 'MI': 0, 'MN': 0}, Original Demand: 1
# Flow at ID: {'MT': 0, 'NV': 0, 'OR': 0, 'UT': 0, 'WA': 0, 'WY': 0}, Original Demand: 1
# Flow at MT: {'ID': 0, 'ND': 0, 'SD': 0, 'WY': 0}, Original Demand: 1
# Flow at WA: {'ID': 0, 'OR': 0}, Original Demand: 1
# Flow at IN: {'IL': 0, 'KY': 0, 'MI': 0, 'OH': 0}, Original Demand: 1
# Flow at KY: {'IL': 0, 'IN': 0, 'MO': 0, 'OH': 0, 'TN': 0, 'VA': 0, 'WV': 0}, Original Demand: 1
# Flow at MI: {'IN': 0, 'OH': 0, 'WI': 0}, Original Demand: 1
# Flow at OH: {'IN': 0, 'KY': 0, 'MI': 0, 'PA': 0, 'WV': 0}, Original Demand: 1
# Flow at WV: {'KY': 0, 'MD': 0, 'OH': 0, 'PA': 0, 'VA': 0}, Original Demand: 1
# Flow at NH: {'MA': 0, 'ME': 0, 'VT': 0}, Original Demand: 1
# Flow at VT: {'MA': 0, 'NH': 0, 'NY': 0}, Original Demand: 1
# Flow at ME: {'NH': 0}, Original Demand: 1
# Flow at ND: {'MN': 0, 'MT': 0, 'SD': 0}, Original Demand: 1
# Node demands: {'AL': 1, 'FL': 1, 'GA': 1, 'MS': 1, 'TN': 1, 'AR': 1, 'LA': 1, 'MO': 1, 'OK': 1, 'TX': 1, 'AZ': 1, 'CA': -48, 'NM': 1, 'NV': 1, 'UT': 1, 'OR': 1, 'CO': 1, 'KS': 1, 'NE': 1, 'WY': 1, 'CT': 1, 'MA': 1, 'NY': 1, 'RI': 1, 'DC': 1, 'MD': 1, 'VA': 1, 'DE': 1, 'NJ': 1, 'PA': 1, 'NC': 1, 'SC': 1, 'IA': 1, 'IL': 1, 'MN': 1, 'SD': 1, 'WI': 1, 'ID': 1, 'MT': 1, 'WA': 1, 'IN': 1, 'KY': 1, 'MI': 1, 'OH': 1, 'WV': 1, 'NH': 1, 'VT': 1, 'ME': 1, 'ND': 1}
# Divergence: {'FL': 0, 'AL': 0, 'GA': 0, 'MS': 0, 'TN': 0, 'NC': 0, 'SC': 0, 'AR': 0, 'LA': 0, 'KY': 0, 'MO': 0, 'VA': 0, 'OK': 0, 'TX': 0, 'IA': 0, 'IL': 0, 'KS': 0, 'NE': 0, 'CO': 0, 'NM': 0, 'CA': 0, 'AZ': 0, 'NV': 0, 'UT': 0, 'OR': 0, 'sink_connector': 16, 'ID': 0, 'WY': 0, 'WA': 0, 'SD': 0, 'MT': 0, 'MA': 0, 'CT': 0, 'NY': 0, 'RI': 0, 'NH': 0, 'VT': 0, 'NJ': 0, 'PA': 0, 'MD': 0, 'DC': 0, 'DE': 0, 'WV': 0, 'OH': 0, 'MN': 0, 'WI': 0, 'IN': 0, 'ND': 0, 'MI': 0, 'ME': 0, 'supersource': -16}
# Flow satisfies all demands: False

# %%
flow = flow_with_demands(G)
div = divergence(flow)

print("Flow values on each edge:")
for s1, flows in flow.items():
    for s2, flow_value in flows.items():
        print(f"{s1} -> {s2}: {flow_value}")
    
print("Node demands:", {n: G.nodes[n]['demand'] for n in G.nodes()})
print("Divergence:", div)
print("Flow satisfies all demands:", all(div[n] == G.nodes[n]['demand'] for n in G.nodes()))
# Out:
# Flow at AL: {'FL': 0, 'GA': 0, 'MS': 0, 'TN': 0}, Original Demand: 1
# Flow at FL: {'AL': 0, 'GA': 0}, Original Demand: 1
# Flow at GA: {'AL': 0, 'FL': 0, 'NC': 0, 'SC': 0, 'TN': 0}, Original Demand: 1
# Flow at MS: {'AL': 0, 'AR': 0, 'LA': 0, 'TN': 0}, Original Demand: 1
# Flow at TN: {'AL': 0, 'AR': 0, 'GA': 0, 'KY': 0, 'MO': 0, 'MS': 0, 'NC': 0, 'VA': 0}, Original Demand: 1
# Flow at AR: {'LA': 0, 'MO': 0, 'MS': 0, 'OK': 0, 'TN': 0, 'TX': 0}, Original Demand: 1
# Flow at LA: {'AR': 0, 'MS': 0, 'TX': 0}, Original Demand: 1
# Flow at MO: {'AR': 0, 'IA': 0, 'IL': 0, 'KS': 0, 'KY': 0, 'NE': 0, 'OK': 0, 'TN': 0}, Original Demand: 1
# Flow at OK: {'AR': 0, 'CO': 0, 'KS': 0, 'MO': 0, 'NM': 0, 'TX': 0}, Original Demand: 1
# Flow at TX: {'AR': 0, 'LA': 0, 'NM': 0, 'OK': 0}, Original Demand: 1
# Flow at AZ: {'CA': 0, 'NM': 0, 'NV': 0, 'UT': 0}, Original Demand: 1
# Flow at CA: {'AZ': 0, 'NV': 0, 'OR': 0, 'sink_connector': 0}, Original Demand: -48
# Flow at NM: {'AZ': 0, 'CO': 0, 'OK': 0, 'TX': 0}, Original Demand: 1
# Flow at NV: {'AZ': 0, 'CA': 0, 'ID': 0, 'OR': 0, 'UT': 0}, Original Demand: 1
# Flow at UT: {'AZ': 0, 'CO': 0, 'ID': 0, 'NV': 0, 'WY': 0}, Original Demand: 1
# Flow at OR: {'CA': 0, 'ID': 0, 'NV': 0, 'WA': 0}, Original Demand: 1
# Flow at CO: {'KS': 0, 'NE': 0, 'NM': 0, 'OK': 0, 'UT': 0, 'WY': 0}, Original Demand: 1
# Flow at KS: {'CO': 0, 'MO': 0, 'NE': 0, 'OK': 0}, Original Demand: 1
# Flow at NE: {'CO': 0, 'IA': 0, 'KS': 0, 'MO': 0, 'SD': 0, 'WY': 0}, Original Demand: 1
# Flow at WY: {'CO': 0, 'ID': 0, 'MT': 0, 'NE': 0, 'SD': 0, 'UT': 0}, Original Demand: 1
# Flow at CT: {'MA': 0, 'NY': 0, 'RI': 0}, Original Demand: 1
# Flow at MA: {'CT': 0, 'NH': 0, 'NY': 0, 'RI': 0, 'VT': 0}, Original Demand: 1
# Flow at NY: {'CT': 0, 'MA': 0, 'NJ': 0, 'PA': 0, 'VT': 0}, Original Demand: 1
# Flow at RI: {'CT': 0, 'MA': 0}, Original Demand: 1
# Flow at DC: {'MD': 0, 'VA': 0}, Original Demand: 1
# Flow at MD: {'DC': 0, 'DE': 0, 'PA': 0, 'VA': 0, 'WV': 0}, Original Demand: 1
# Flow at VA: {'DC': 0, 'KY': 0, 'MD': 0, 'NC': 0, 'TN': 0, 'WV': 0}, Original Demand: 1
# Flow at DE: {'MD': 0, 'NJ': 0, 'PA': 0}, Original Demand: 1
# Flow at NJ: {'DE': 0, 'NY': 0, 'PA': 0}, Original Demand: 1
# Flow at PA: {'DE': 0, 'MD': 0, 'NJ': 0, 'NY': 0, 'OH': 0, 'WV': 0}, Original Demand: 1
# Flow at NC: {'GA': 0, 'SC': 0, 'TN': 0, 'VA': 0}, Original Demand: 1
# Flow at SC: {'GA': 0, 'NC': 0}, Original Demand: 1
# Flow at IA: {'IL': 0, 'MN': 0, 'MO': 0, 'NE': 0, 'SD': 0, 'WI': 0}, Original Demand: 1
# Flow at IL: {'IA': 0, 'IN': 0, 'KY': 0, 'MO': 0, 'WI': 0}, Original Demand: 1
# Flow at MN: {'IA': 0, 'ND': 0, 'SD': 0, 'WI': 0}, Original Demand: 1
# Flow at SD: {'IA': 0, 'MN': 0, 'MT': 0, 'ND': 0, 'NE': 0, 'WY': 0}, Original Demand: 1
# Flow at WI: {'IA': 0, 'IL': 0, 'MI': 0, 'MN': 0}, Original Demand: 1
# Flow at ID: {'MT': 0, 'NV': 0, 'OR': 0, 'UT': 0, 'WA': 0, 'WY': 0}, Original Demand: 1
# Flow at MT: {'ID': 0, 'ND': 0, 'SD': 0, 'WY': 0}, Original Demand: 1
# Flow at WA: {'ID': 0, 'OR': 0}, Original Demand: 1
# Flow at IN: {'IL': 0, 'KY': 0, 'MI': 0, 'OH': 0}, Original Demand: 1
# Flow at KY: {'IL': 0, 'IN': 0, 'MO': 0, 'OH': 0, 'TN': 0, 'VA': 0, 'WV': 0}, Original Demand: 1
# Flow at MI: {'IN': 0, 'OH': 0, 'WI': 0}, Original Demand: 1
# Flow at OH: {'IN': 0, 'KY': 0, 'MI': 0, 'PA': 0, 'WV': 0}, Original Demand: 1
# Flow at WV: {'KY': 0, 'MD': 0, 'OH': 0, 'PA': 0, 'VA': 0}, Original Demand: 1
# Flow at NH: {'MA': 0, 'ME': 0, 'VT': 0}, Original Demand: 1
# Flow at VT: {'MA': 0, 'NH': 0, 'NY': 0}, Original Demand: 1
# Flow at ME: {'NH': 0}, Original Demand: 1
# Flow at ND: {'MN': 0, 'MT': 0, 'SD': 0}, Original Demand: 1
# Flow values on each edge:
# AL -> FL: 0
# AL -> GA: 0
# AL -> MS: 0
# AL -> TN: 0
# FL -> AL: 0
# FL -> GA: 0
# GA -> AL: 0
# GA -> FL: 0
# GA -> NC: 0
# GA -> SC: 0
# GA -> TN: 0
# MS -> AL: 0
# MS -> AR: 0
# MS -> LA: 0
# MS -> TN: 0
# TN -> AL: 0
# TN -> AR: 0
# TN -> GA: 0
# TN -> KY: 0
# TN -> MO: 0
# TN -> MS: 0
# TN -> NC: 0
# TN -> VA: 0
# AR -> LA: 0
# AR -> MO: 0
# AR -> MS: 0
# AR -> OK: 0
# AR -> TN: 0
# AR -> TX: 0
# LA -> AR: 0
# LA -> MS: 0
# LA -> TX: 0
# MO -> AR: 0
# MO -> IA: 0
# MO -> IL: 0
# MO -> KS: 0
# MO -> KY: 0
# MO -> NE: 0
# MO -> OK: 0
# MO -> TN: 0
# OK -> AR: 0
# OK -> CO: 0
# OK -> KS: 0
# OK -> MO: 0
# OK -> NM: 0
# OK -> TX: 0
# TX -> AR: 0
# TX -> LA: 0
# TX -> NM: 0
# TX -> OK: 0
# AZ -> CA: 0
# AZ -> NM: 0
# AZ -> NV: 0
# AZ -> UT: 0
# CA -> AZ: 0
# CA -> NV: 0
# CA -> OR: 0
# CA -> sink_connector: 0
# NM -> AZ: 0
# NM -> CO: 0
# NM -> OK: 0
# NM -> TX: 0
# NV -> AZ: 0
# NV -> CA: 0
# NV -> ID: 0
# NV -> OR: 0
# NV -> UT: 0
# UT -> AZ: 0
# UT -> CO: 0
# UT -> ID: 0
# UT -> NV: 0
# UT -> WY: 0
# OR -> CA: 0
# OR -> ID: 0
# OR -> NV: 0
# OR -> WA: 0
# CO -> KS: 0
# CO -> NE: 0
# CO -> NM: 0
# CO -> OK: 0
# CO -> UT: 0
# CO -> WY: 0
# KS -> CO: 0
# KS -> MO: 0
# KS -> NE: 0
# KS -> OK: 0
# NE -> CO: 0
# NE -> IA: 0
# NE -> KS: 0
# NE -> MO: 0
# NE -> SD: 0
# NE -> WY: 0
# WY -> CO: 0
# WY -> ID: 0
# WY -> MT: 0
# WY -> NE: 0
# WY -> SD: 0
# WY -> UT: 0
# CT -> MA: 0
# CT -> NY: 0
# CT -> RI: 0
# MA -> CT: 0
# MA -> NH: 0
# MA -> NY: 0
# MA -> RI: 0
# MA -> VT: 0
# NY -> CT: 0
# NY -> MA: 0
# NY -> NJ: 0
# NY -> PA: 0
# NY -> VT: 0
# RI -> CT: 0
# RI -> MA: 0
# DC -> MD: 0
# DC -> VA: 0
# MD -> DC: 0
# MD -> DE: 0
# MD -> PA: 0
# MD -> VA: 0
# MD -> WV: 0
# VA -> DC: 0
# VA -> KY: 0
# VA -> MD: 0
# VA -> NC: 0
# VA -> TN: 0
# VA -> WV: 0
# DE -> MD: 0
# DE -> NJ: 0
# DE -> PA: 0
# NJ -> DE: 0
# NJ -> NY: 0
# NJ -> PA: 0
# PA -> DE: 0
# PA -> MD: 0
# PA -> NJ: 0
# PA -> NY: 0
# PA -> OH: 0
# PA -> WV: 0
# NC -> GA: 0
# NC -> SC: 0
# NC -> TN: 0
# NC -> VA: 0
# SC -> GA: 0
# SC -> NC: 0
# IA -> IL: 0
# IA -> MN: 0
# IA -> MO: 0
# IA -> NE: 0
# IA -> SD: 0
# IA -> WI: 0
# IL -> IA: 0
# IL -> IN: 0
# IL -> KY: 0
# IL -> MO: 0
# IL -> WI: 0
# MN -> IA: 0
# MN -> ND: 0
# MN -> SD: 0
# MN -> WI: 0
# SD -> IA: 0
# SD -> MN: 0
# SD -> MT: 0
# SD -> ND: 0
# SD -> NE: 0
# SD -> WY: 0
# WI -> IA: 0
# WI -> IL: 0
# WI -> MI: 0
# WI -> MN: 0
# ID -> MT: 0
# ID -> NV: 0
# ID -> OR: 0
# ID -> UT: 0
# ID -> WA: 0
# ID -> WY: 0
# MT -> ID: 0
# MT -> ND: 0
# MT -> SD: 0
# MT -> WY: 0
# WA -> ID: 0
# WA -> OR: 0
# IN -> IL: 0
# IN -> KY: 0
# IN -> MI: 0
# IN -> OH: 0
# KY -> IL: 0
# KY -> IN: 0
# KY -> MO: 0
# KY -> OH: 0
# KY -> TN: 0
# KY -> VA: 0
# KY -> WV: 0
# MI -> IN: 0
# MI -> OH: 0
# MI -> WI: 0
# OH -> IN: 0
# OH -> KY: 0
# OH -> MI: 0
# OH -> PA: 0
# OH -> WV: 0
# WV -> KY: 0
# WV -> MD: 0
# WV -> OH: 0
# WV -> PA: 0
# WV -> VA: 0
# NH -> MA: 0
# NH -> ME: 0
# NH -> VT: 0
# VT -> MA: 0
# VT -> NH: 0
# VT -> NY: 0
# ME -> NH: 0
# ND -> MN: 0
# ND -> MT: 0
# ND -> SD: 0
# supersource -> sink_connector: 16
# Node demands: {'AL': 1, 'FL': 1, 'GA': 1, 'MS': 1, 'TN': 1, 'AR': 1, 'LA': 1, 'MO': 1, 'OK': 1, 'TX': 1, 'AZ': 1, 'CA': -48, 'NM': 1, 'NV': 1, 'UT': 1, 'OR': 1, 'CO': 1, 'KS': 1, 'NE': 1, 'WY': 1, 'CT': 1, 'MA': 1, 'NY': 1, 'RI': 1, 'DC': 1, 'MD': 1, 'VA': 1, 'DE': 1, 'NJ': 1, 'PA': 1, 'NC': 1, 'SC': 1, 'IA': 1, 'IL': 1, 'MN': 1, 'SD': 1, 'WI': 1, 'ID': 1, 'MT': 1, 'WA': 1, 'IN': 1, 'KY': 1, 'MI': 1, 'OH': 1, 'WV': 1, 'NH': 1, 'VT': 1, 'ME': 1, 'ND': 1}
# Divergence: {'FL': 0, 'AL': 0, 'GA': 0, 'MS': 0, 'TN': 0, 'NC': 0, 'SC': 0, 'AR': 0, 'LA': 0, 'KY': 0, 'MO': 0, 'VA': 0, 'OK': 0, 'TX': 0, 'IA': 0, 'IL': 0, 'KS': 0, 'NE': 0, 'CO': 0, 'NM': 0, 'CA': 0, 'AZ': 0, 'NV': 0, 'UT': 0, 'OR': 0, 'sink_connector': 16, 'ID': 0, 'WY': 0, 'WA': 0, 'SD': 0, 'MT': 0, 'MA': 0, 'CT': 0, 'NY': 0, 'RI': 0, 'NH': 0, 'VT': 0, 'NJ': 0, 'PA': 0, 'MD': 0, 'DC': 0, 'DE': 0, 'WV': 0, 'OH': 0, 'MN': 0, 'WI': 0, 'IN': 0, 'ND': 0, 'MI': 0, 'ME': 0, 'supersource': -16}
# Flow satisfies all demands: False
